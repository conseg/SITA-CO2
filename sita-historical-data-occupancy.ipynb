# %%
import pandas as pd
import numpy as np
import sklearn
import warnings
import statistics

from matplotlib import pyplot as plt
warnings.filterwarnings("ignore")

from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import Ridge
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
files = ['/kaggle/input/historical-data-occupancy-sita/historical_data_occupancy4444.csv',
         '/kaggle/input/historical-data-occupancy-sita/historical_data_occupancy3444.csv',
         '/kaggle/input/historical-data-occupancy-sita/historical_data_occupancy2444.csv',
         '/kaggle/input/historical-data-occupancy-sita/historical_data_occupancy1444.csv',
         '/kaggle/input/historical-data-occupancy-sita/historical_data_occupancy0444.csv',
         '/kaggle/input/historical-data-occupancy-sita/historical_data_occupancy4434.csv',
         '/kaggle/input/historical-data-occupancy-sita/historical_data_occupancy4424.csv',
         '/kaggle/input/historical-data-occupancy-sita/historical_data_occupancy4414.csv',
         '/kaggle/input/historical-data-occupancy-sita/historical_data_occupancy4404.csv',
         '/kaggle/input/historical-data-occupancy-sita/historical_data_occupancy4443.csv',
         '/kaggle/input/historical-data-occupancy-sita/historical_data_occupancy4442.csv',
         '/kaggle/input/historical-data-occupancy-sita/historical_data_occupancy4441.csv',
         '/kaggle/input/historical-data-occupancy-sita/historical_data_occupancy4440.csv']

# %%
def resultsPredictionKFold(X_train, y_train, cv, model):
    mae = cross_val_score(model, X_train, y_train, scoring='neg_mean_absolute_error', cv=cv)
    rmse = cross_val_score(model, X_train, y_train, scoring='neg_root_mean_squared_error', cv=cv)
    r2 = cross_val_score(model, X_train, y_train, scoring='r2', cv=cv)
    result = [r2, mae, rmse]
    return result

# %%
np.random.seed(10)
for filename in files:    
    src = os.path.join(dirname, filename)
    print()
    print(src)
    print()
    
    sita = src.split('.')[0][-4:]
    data = pd.read_csv(src, sep=";", skiprows=[0])
    
    if(sita == '4440'):
        col_names = ['Room', 'Zone', 'Date', 'Time', 'CO2', 'Temperature', 'Humidity', 'Brightness', 'Unnamed1', 'Occupancy', 'Unnamed2']
        data.columns = col_names
        data = data.drop(columns=['Unnamed1', 'Unnamed2'])
    else:
        col_names = ['Room', 'Zone', 'Date', 'Time', 'CO2', 'Temperature', 'Humidity', 'Brightness', 'Occupancy', 'Unnamed1']    
        data.columns = col_names
        data = data.drop(columns=['Unnamed1'])    

    data = data.replace(' deleted', 0)
    data = data.replace('deleted', 0)
    data = data.replace('1st Floor', 1)
    data = data.replace('4th Floor', 4)
    data = data.replace('USB', 0)
    
    data['Room'] = pd.to_numeric(data['Room'], errors='coerce')
    data['Zone'] = pd.to_numeric(data['Zone'], errors='coerce')
    data['Date'] = pd.to_numeric(data['Date'], errors='coerce')
    data['Time'] = pd.to_numeric(data['Time'], errors='coerce')
    data['CO2'] = pd.to_numeric(data['CO2'], errors='coerce')
    data['Temperature'] = pd.to_numeric(data['Temperature'], errors='coerce')
    data['Humidity'] = pd.to_numeric(data['Humidity'], errors='coerce')
    data['Brightness'] = pd.to_numeric(data['Brightness'], errors='coerce')
    data['Occupancy'] = pd.to_numeric(data['Occupancy'], errors='coerce')

    X = data[['Room', 'Zone', 'Date', 'Time', 'Temperature', 'Humidity', 'Brightness', 'Occupancy']]
    y = data['CO2']
        
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    cv = KFold(n_splits=10, shuffle=True)
    
    modelRF = RandomForestRegressor()
    modelRF.fit(X_train, y_train)
    y_pred = modelRF.predict(X_test)
    resultsRF_KFold = resultsPredictionKFold(X_train, y_train, cv, modelRF)
    
    print("Modelo RF")
    print()

    print("Métrica R2")
    print("Média: %.6f" %(abs(resultsRF_KFold[0].mean())))
    print("Desvio Padrão: %.6f" %abs(resultsRF_KFold[0].std()))
    print("Mediana: %.6f" %abs(statistics.median(resultsRF_KFold[0])))
    print()

    print("Métrica MAE")
    print("Média: %.6f" %abs(resultsRF_KFold[1].mean()))
    print("Desvio Padrão: %.6f" %abs(resultsRF_KFold[1].std()))
    print("Mediana: %.6f" %abs(statistics.median(resultsRF_KFold[1])))
    print()

    print("Métrica RMSE")
    print("Média: %.6f" %abs(resultsRF_KFold[2].mean()))
    print("Desvio Padrão: %.6f" %abs(resultsRF_KFold[2].std()))
    print("Mediana: %.6f" %abs(statistics.median(resultsRF_KFold[2])))
    print()
        
    modelRR = Ridge()
    modelRR.fit(X_train, y_train)
    y_pred = modelRR.predict(X_test)
    resultsRR_KFold = resultsPredictionKFold(X_train, y_train, cv, modelRR)

    print("Modelo RR")
    print()

    print("Métrica R2")
    print("Média: %.6f" %(abs(resultsRR_KFold[0].mean())))
    print("Desvio Padrão: %.6f" %abs(resultsRR_KFold[0].std()))
    print("Mediana: %.6f" %abs(statistics.median(resultsRR_KFold[0])))
    print()

    print("Métrica MAE")
    print("Média: %.6f" %abs(resultsRR_KFold[1].mean()))
    print("Desvio Padrão: %.6f" %abs(resultsRR_KFold[1].std()))
    print("Mediana: %.6f" %abs(statistics.median(resultsRR_KFold[1])))
    print()

    print("Métrica RMSE")
    print("Média: %.6f" %abs(resultsRR_KFold[2].mean()))
    print("Desvio Padrão: %.6f" %abs(resultsRR_KFold[2].std()))
    print("Mediana: %.6f" %abs(statistics.median(resultsRR_KFold[2])))
    print()
        
    modelLR = LinearRegression()
    modelLR.fit(X_train, y_train)
    y_pred = modelLR.predict(X_test)
    resultsLR_KFold = resultsPredictionKFold(X_train, y_train, cv, modelLR)

    print("Modelo LR")
    print()

    print("Métrica R2")
    print("Média: %.6f" %(abs(resultsLR_KFold[0].mean())))
    print("Desvio Padrão: %.6f" %abs(resultsLR_KFold[0].std()))
    print("Mediana: %.6f" %abs(statistics.median(resultsLR_KFold[0])))
    print()

    print("Métrica MAE")
    print("Média: %.6f" %abs(resultsLR_KFold[1].mean()))
    print("Desvio Padrão: %.6f" %abs(resultsLR_KFold[1].std()))
    print("Mediana: %.6f" %abs(statistics.median(resultsLR_KFold[1])))
    print()

    print("Métrica RMSE")
    print("Média: %.6f" %abs(resultsLR_KFold[2].mean()))
    print("Desvio Padrão: %.6f" %abs(resultsLR_KFold[2].std()))
    print("Mediana: %.6f" %abs(statistics.median(resultsLR_KFold[2])))
    print()
        
    modelDT = DecisionTreeRegressor()
    modelDT.fit(X_train, y_train)
    y_pred = modelDT.predict(X_test)
    resultsDT_KFold = resultsPredictionKFold(X_train, y_train, cv, modelDT)

    print("Modelo DT")
    print()
    
    print("Métrica R2")
    print("Média: %.6f" %(abs(resultsDT_KFold[0].mean())))
    print("Desvio Padrão: %.6f" %abs(resultsDT_KFold[0].std()))
    print("Mediana: %.6f" %abs(statistics.median(resultsDT_KFold[0])))
    print()

    print("Métrica MAE")
    print("Média: %.6f" %abs(resultsDT_KFold[1].mean()))
    print("Desvio Padrão: %.6f" %abs(resultsDT_KFold[1].std()))
    print("Mediana: %.6f" %abs(statistics.median(resultsDT_KFold[1])))
    print()

    print("Métrica RMSE")
    print("Média: %.6f" %abs(resultsDT_KFold[2].mean()))
    print("Desvio Padrão: %.6f" %abs(resultsDT_KFold[2].std()))
    print("Mediana: %.6f" %abs(statistics.median(resultsDT_KFold[2])))
    print()
        
    modelGBR = GradientBoostingRegressor()
    modelGBR.fit(X_train, y_train)
    y_pred = modelGBR.predict(X_test)
    resultsGBR_KFold = resultsPredictionKFold(X_train, y_train, cv, modelGBR)

    print("Modelo GBR")
    print()

    print("Métrica R2")
    print("Média: %.6f" %(abs(resultsGBR_KFold[0].mean())))
    print("Desvio Padrão: %.6f" %abs(resultsGBR_KFold[0].std()))
    print("Mediana: %.6f" %abs(statistics.median(resultsGBR_KFold[0])))
    print()
    
    print("Métrica MAE")
    print("Média: %.6f" %abs(resultsGBR_KFold[1].mean()))
    print("Desvio Padrão: %.6f" %abs(resultsGBR_KFold[1].std()))
    print("Mediana: %.6f" %abs(statistics.median(resultsGBR_KFold[1])))
    print()

    print("Métrica RMSE")
    print("Média: %.6f" %abs(resultsGBR_KFold[2].mean()))
    print("Desvio Padrão: %.6f" %abs(resultsGBR_KFold[2].std()))
    print("Mediana: %.6f" %abs(statistics.median(resultsGBR_KFold[2])))
    print()
# Out:
# /kaggle/input/historical-data-occupancy-sita/historical_data_occupancy4444.csv
#
# Modelo RF
#
# Métrica R2
# Média: 0.731242
# Desvio Padrão: 0.006793
# Mediana: 0.732633
#
# Métrica MAE
# Média: 32.473938
# Desvio Padrão: 0.371416
# Mediana: 32.403389
#
# Métrica RMSE
# Média: 62.993307
# Desvio Padrão: 0.906687
# Mediana: 63.153823
#
# Modelo RR
#
# Métrica R2
# Média: 0.109082
# Desvio Padrão: 0.006534
# Mediana: 0.109407
#
# Métrica MAE
# Média: 87.617685
# Desvio Padrão: 0.508531
# Mediana: 87.693068
#
# Métrica RMSE
# Média: 114.805525
# Desvio Padrão: 0.795343
# Mediana: 114.757042
#
# Modelo LR
#
# Métrica R2
# Média: 0.109183
# Desvio Padrão: 0.005188
# Mediana: 0.109502
#
# Métrica MAE
# Média: 87.617377
# Desvio Padrão: 0.577020
# Mediana: 87.690497
#
# Métrica RMSE
# Média: 114.808220
# Desvio Padrão: 0.624546
# Mediana: 114.613968
#
# Modelo DT
#
# Métrica R2
# Média: 0.540267
# Desvio Padrão: 0.014621
# Mediana: 0.535306
#
# Métrica MAE
# Média: 34.310159
# Desvio Padrão: 0.556021
# Mediana: 34.413752
#
# Métrica RMSE
# Média: 83.447758
# Desvio Padrão: 1.040187
# Mediana: 83.352951
#
# Modelo GBR
#
# Métrica R2
# Média: 0.333253
# Desvio Padrão: 0.007234
# Mediana: 0.333640
#
# Métrica MAE
# Média: 73.207048
# Desvio Padrão: 0.415766
# Mediana: 73.197277
#
# Métrica RMSE
# Média: 99.386599
# Desvio Padrão: 0.535400
# Mediana: 99.381814
#
#
# /kaggle/input/historical-data-occupancy-sita/historical_data_occupancy3444.csv
#
# Modelo RF
#
# Métrica R2
# Média: 0.728018
# Desvio Padrão: 0.005930
# Mediana: 0.727715
#
# Métrica MAE
# Média: 32.643786
# Desvio Padrão: 0.452902
# Mediana: 32.714724
#
# Métrica RMSE
# Média: 63.243650
# Desvio Padrão: 0.872677
# Mediana: 63.056848
#
# Modelo RR
#
# Métrica R2
# Média: 0.106584
# Desvio Padrão: 0.004945
# Mediana: 0.106608
#
# Métrica MAE
# Média: 87.655247
# Desvio Padrão: 0.492811
# Mediana: 87.554083
#
# Métrica RMSE
# Média: 114.906156
# Desvio Padrão: 0.715066
# Mediana: 114.895093
#
# Modelo LR
#
# Métrica R2
# Média: 0.106465
# Desvio Padrão: 0.005412
# Mediana: 0.106361
#
# Métrica MAE
# Média: 87.653235
# Desvio Padrão: 0.500607
# Mediana: 87.679401
#
# Métrica RMSE
# Média: 114.904278
# Desvio Padrão: 0.832038
# Mediana: 114.630807
#
# Modelo DT
#
# Métrica R2
# Média: 0.537188
# Desvio Padrão: 0.010617
# Mediana: 0.534157
#
# Métrica MAE
# Média: 34.449144
# Desvio Padrão: 0.549435
# Mediana: 34.347402
#
# Métrica RMSE
# Média: 83.061163
# Desvio Padrão: 0.857059
# Mediana: 82.937744
#
# Modelo GBR
#
# Métrica R2
# Média: 0.325809
# Desvio Padrão: 0.007659
# Mediana: 0.326219
#
# Métrica MAE
# Média: 73.627865
# Desvio Padrão: 0.316585
# Mediana: 73.632597
#
# Métrica RMSE
# Média: 99.911612
# Desvio Padrão: 0.840974
# Mediana: 99.832205
#
#
# /kaggle/input/historical-data-occupancy-sita/historical_data_occupancy2444.csv
#
# Modelo RF
#
# Métrica R2
# Média: 0.730013
# Desvio Padrão: 0.009872
# Mediana: 0.728515
#
# Métrica MAE
# Média: 32.510991
# Desvio Padrão: 0.367837
# Mediana: 32.538600
#
# Métrica RMSE
# Média: 63.080061
# Desvio Padrão: 0.835775
# Mediana: 63.176709
#
# Modelo RR
#
# Métrica R2
# Média: 0.106412
# Desvio Padrão: 0.005519
# Mediana: 0.105639
#
# Métrica MAE
# Média: 87.599119
# Desvio Padrão: 0.517700
# Mediana: 87.757539
#
# Métrica RMSE
# Média: 114.780636
# Desvio Padrão: 1.049171
# Mediana: 114.822815
#
# Modelo LR
#
# Métrica R2
# Média: 0.106372
# Desvio Padrão: 0.002820
# Mediana: 0.106191
#
# Métrica MAE
# Média: 87.599537
# Desvio Padrão: 0.478126
# Mediana: 87.708113
#
# Métrica RMSE
# Média: 114.783864
# Desvio Padrão: 0.900333
# Mediana: 114.914917
#
# Modelo DT
#
# Métrica R2
# Média: 0.531016
# Desvio Padrão: 0.010534
# Mediana: 0.531109
#
# Métrica MAE
# Média: 34.231053
# Desvio Padrão: 0.606326
# Mediana: 34.023716
#
# Métrica RMSE
# Média: 82.826191
# Desvio Padrão: 0.924247
# Mediana: 82.740241
#
# Modelo GBR
#
# Métrica R2
# Média: 0.328520
# Desvio Padrão: 0.005653
# Mediana: 0.329911
#
# Métrica MAE
# Média: 73.531033
# Desvio Padrão: 0.665295
# Mediana: 73.371489
#
# Métrica RMSE
# Média: 99.654155
# Desvio Padrão: 0.542756
# Mediana: 99.639383
#
#
# /kaggle/input/historical-data-occupancy-sita/historical_data_occupancy1444.csv
#
# Modelo RF
#
# Métrica R2
# Média: 0.722705
# Desvio Padrão: 0.006856
# Mediana: 0.723955
#
# Métrica MAE
# Média: 33.430881
# Desvio Padrão: 0.355713
# Mediana: 33.522732
#
# Métrica RMSE
# Média: 63.981535
# Desvio Padrão: 0.672631
# Mediana: 63.910898
#
# Modelo RR
#
# Métrica R2
# Média: 0.106343
# Desvio Padrão: 0.004622
# Mediana: 0.104887
#
# Métrica MAE
# Média: 87.626122
# Desvio Padrão: 0.422077
# Mediana: 87.629085
#
# Métrica RMSE
# Média: 114.813329
# Desvio Padrão: 0.587333
# Mediana: 114.701310
#
# Modelo LR
#
# Métrica R2
# Média: 0.106341
# Desvio Padrão: 0.003208
# Mediana: 0.105678
#
# Métrica MAE
# Média: 87.625014
# Desvio Padrão: 0.565937
# Mediana: 87.518182
#
# Métrica RMSE
# Média: 114.808375
# Desvio Padrão: 0.895603
# Mediana: 114.645527
#
# Modelo DT
#
# Métrica R2
# Média: 0.509528
# Desvio Padrão: 0.009307
# Mediana: 0.510267
#
# Métrica MAE
# Média: 35.484831
# Desvio Padrão: 0.558768
# Mediana: 35.428175
#
# Métrica RMSE
# Média: 84.676881
# Desvio Padrão: 1.314544
# Mediana: 84.370238
#
# Modelo GBR
#
# Métrica R2
# Média: 0.306834
# Desvio Padrão: 0.002586
# Mediana: 0.306798
#
# Métrica MAE
# Média: 74.730250
# Desvio Padrão: 0.238786
# Mediana: 74.737530
#
# Métrica RMSE
# Média: 101.070285
# Desvio Padrão: 0.767899
# Mediana: 101.126324
#
#
# /kaggle/input/historical-data-occupancy-sita/historical_data_occupancy0444.csv
#
# Modelo RF
#
# Métrica R2
# Média: 0.718570
# Desvio Padrão: 0.007098
# Mediana: 0.718945
#
# Métrica MAE
# Média: 33.628468
# Desvio Padrão: 0.395104
# Mediana: 33.620654
#
# Métrica RMSE
# Média: 64.310793
# Desvio Padrão: 0.545576
# Mediana: 64.174114
#
# Modelo RR
#
# Métrica R2
# Média: 0.106972
# Desvio Padrão: 0.007170
# Mediana: 0.106103
#
# Métrica MAE
# Média: 87.572028
# Desvio Padrão: 0.707594
# Mediana: 87.498740
#
# Métrica RMSE
# Média: 114.808723
# Desvio Padrão: 0.953518
# Mediana: 114.445906
#
# Modelo LR
#
# Métrica R2
# Média: 0.107109
# Desvio Padrão: 0.003716
# Mediana: 0.106427
#
# Métrica MAE
# Média: 87.571644
# Desvio Padrão: 0.458747
# Mediana: 87.541635
#
# Métrica RMSE
# Média: 114.811590
# Desvio Padrão: 0.565351
# Mediana: 114.729365
#
# Modelo DT
#
# Métrica R2
# Média: 0.511554
# Desvio Padrão: 0.020524
# Mediana: 0.519331
#
# Métrica MAE
# Média: 35.489652
# Desvio Padrão: 0.342530
# Mediana: 35.549961
#
# Métrica RMSE
# Média: 84.517925
# Desvio Padrão: 1.601623
# Mediana: 84.191158
#
# Modelo GBR
#
# Métrica R2
# Média: 0.303064
# Desvio Padrão: 0.005626
# Mediana: 0.304500
#
# Métrica MAE
# Média: 74.857873
# Desvio Padrão: 0.458982
# Mediana: 74.868665
#
# Métrica RMSE
# Média: 101.391289
# Desvio Padrão: 0.802905
# Mediana: 101.199202
#
#
# /kaggle/input/historical-data-occupancy-sita/historical_data_occupancy4434.csv
#
# Modelo RF
#
# Métrica R2
# Média: 0.678824
# Desvio Padrão: 0.009605
# Mediana: 0.677652
#
# Métrica MAE
# Média: 36.715222
# Desvio Padrão: 0.350798
# Mediana: 36.579838
#
# Métrica RMSE
# Média: 68.816756
# Desvio Padrão: 0.701863
# Mediana: 68.700965
#
# Modelo RR
#
# Métrica R2
# Média: 0.109413
# Desvio Padrão: 0.005695
# Mediana: 0.110432
#
# Métrica MAE
# Média: 87.360287
# Desvio Padrão: 0.512413
# Mediana: 87.189515
#
# Métrica RMSE
# Média: 114.541998
# Desvio Padrão: 0.462554
# Mediana: 114.537386
#
# Modelo LR
#
# Métrica R2
# Média: 0.109418
# Desvio Padrão: 0.004607
# Mediana: 0.109932
#
# Métrica MAE
# Média: 87.359390
# Desvio Padrão: 0.660977
# Mediana: 87.514847
#
# Métrica RMSE
# Média: 114.539849
# Desvio Padrão: 0.671267
# Mediana: 114.342585
#
# Modelo DT
#
# Métrica R2
# Média: 0.503442
# Desvio Padrão: 0.013986
# Mediana: 0.507375
#
# Métrica MAE
# Média: 39.582556
# Desvio Padrão: 0.527292
# Mediana: 39.551971
#
# Métrica RMSE
# Média: 85.558866
# Desvio Padrão: 1.400119
# Mediana: 85.896497
#
# Modelo GBR
#
# Métrica R2
# Média: 0.330163
# Desvio Padrão: 0.005175
# Mediana: 0.330111
#
# Métrica MAE
# Média: 73.205394
# Desvio Padrão: 0.289072
# Mediana: 73.120982
#
# Métrica RMSE
# Média: 99.223945
# Desvio Padrão: 0.557200
# Mediana: 99.269060
#
#
# /kaggle/input/historical-data-occupancy-sita/historical_data_occupancy4424.csv
#
# Modelo RF
#
# Métrica R2
# Média: 0.637941
# Desvio Padrão: 0.004268
# Mediana: 0.639185
#
# Métrica MAE
# Média: 39.851888
# Desvio Padrão: 0.567305
# Mediana: 39.935215
#
# Métrica RMSE
# Média: 73.095402
# Desvio Padrão: 0.419427
# Mediana: 73.155052
#
# Modelo RR
#
# Métrica R2
# Média: 0.099557
# Desvio Padrão: 0.007132
# Mediana: 0.099982
#
# Métrica MAE
# Média: 88.075236
# Desvio Padrão: 0.517338
# Mediana: 88.122338
#
# Métrica RMSE
# Média: 115.196767
# Desvio Padrão: 0.986270
# Mediana: 115.424155
#
# Modelo LR
#
# Métrica R2
# Média: 0.099642
# Desvio Padrão: 0.003371
# Mediana: 0.099824
#
# Métrica MAE
# Média: 88.073804
# Desvio Padrão: 0.690444
# Mediana: 87.970819
#
# Métrica RMSE
# Média: 115.194958
# Desvio Padrão: 0.982125
# Mediana: 115.055104
#
# Modelo DT
#
# Métrica R2
# Média: 0.488916
# Desvio Padrão: 0.014782
# Mediana: 0.483765
#
# Métrica MAE
# Média: 41.597331
# Desvio Padrão: 0.624572
# Mediana: 41.395277
#
# Métrica RMSE
# Média: 87.254062
# Desvio Padrão: 1.084534
# Mediana: 87.265605
#
# Modelo GBR
#
# Métrica R2
# Média: 0.271390
# Desvio Padrão: 0.005133
# Mediana: 0.271485
#
# Métrica MAE
# Média: 77.530555
# Desvio Padrão: 0.469525
# Mediana: 77.416004
#
# Métrica RMSE
# Média: 103.560034
# Desvio Padrão: 0.680544
# Mediana: 103.432354
#
#
# /kaggle/input/historical-data-occupancy-sita/historical_data_occupancy4414.csv
#
# Modelo RF
#
# Métrica R2
# Média: 0.597233
# Desvio Padrão: 0.007403
# Mediana: 0.595605
#
# Métrica MAE
# Média: 43.245260
# Desvio Padrão: 0.382569
# Mediana: 43.232832
#
# Métrica RMSE
# Média: 77.282801
# Desvio Padrão: 1.142891
# Mediana: 77.392069
#
# Modelo RR
#
# Métrica R2
# Média: 0.100645
# Desvio Padrão: 0.004574
# Mediana: 0.100986
#
# Métrica MAE
# Média: 88.149489
# Desvio Padrão: 0.587396
# Mediana: 88.105929
#
# Métrica RMSE
# Média: 115.261588
# Desvio Padrão: 0.797330
# Mediana: 115.349578
#
# Modelo LR
#
# Métrica R2
# Média: 0.100691
# Desvio Padrão: 0.005162
# Mediana: 0.101486
#
# Métrica MAE
# Média: 88.146978
# Desvio Padrão: 0.328918
# Mediana: 88.116629
#
# Métrica RMSE
# Média: 115.263864
# Desvio Padrão: 0.625089
# Mediana: 115.357632
#
# Modelo DT
#
# Métrica R2
# Média: 0.469885
# Desvio Padrão: 0.016292
# Mediana: 0.470276
#
# Métrica MAE
# Média: 44.264355
# Desvio Padrão: 0.547857
# Mediana: 44.006236
#
# Métrica RMSE
# Média: 88.503029
# Desvio Padrão: 1.242778
# Mediana: 88.462215
#
# Modelo GBR
#
# Métrica R2
# Média: 0.250264
# Desvio Padrão: 0.003962
# Mediana: 0.251499
#
# Métrica MAE
# Média: 78.960998
# Desvio Padrão: 0.449920
# Mediana: 78.953271
#
# Métrica RMSE
# Média: 105.282719
# Desvio Padrão: 0.622435
# Mediana: 105.452097
#
#
# /kaggle/input/historical-data-occupancy-sita/historical_data_occupancy4404.csv
#
# Modelo RF
#
# Métrica R2
# Média: 0.519840
# Desvio Padrão: 0.006463
# Mediana: 0.520970
#
# Métrica MAE
# Média: 49.849175
# Desvio Padrão: 0.540667
# Mediana: 50.032537
#
# Métrica RMSE
# Média: 84.198708
# Desvio Padrão: 1.183871
# Mediana: 84.205156
#
# Modelo RR
#
# Métrica R2
# Média: 0.089272
# Desvio Padrão: 0.003632
# Mediana: 0.089585
#
# Métrica MAE
# Média: 88.910917
# Desvio Padrão: 0.562249
# Mediana: 88.754955
#
# Métrica RMSE
# Média: 116.200238
# Desvio Padrão: 1.113628
# Mediana: 116.286289
#
# Modelo LR
#
# Métrica R2
# Média: 0.089229
# Desvio Padrão: 0.004862
# Mediana: 0.089647
#
# Métrica MAE
# Média: 88.908053
# Desvio Padrão: 0.443642
# Mediana: 88.856999
#
# Métrica RMSE
# Média: 116.200689
# Desvio Padrão: 0.927890
# Mediana: 116.367543
#
# Modelo DT
#
# Métrica R2
# Média: 0.376260
# Desvio Padrão: 0.012006
# Mediana: 0.377006
#
# Métrica MAE
# Média: 50.929976
# Desvio Padrão: 0.510715
# Mediana: 50.880671
#
# Métrica RMSE
# Média: 95.993936
# Desvio Padrão: 0.806126
# Mediana: 96.198973
#
# Modelo GBR
#
# Métrica R2
# Média: 0.189905
# Desvio Padrão: 0.005499
# Mediana: 0.190986
#
# Métrica MAE
# Média: 82.236458
# Desvio Padrão: 0.511744
# Mediana: 82.100607
#
# Métrica RMSE
# Média: 109.575320
# Desvio Padrão: 1.132981
# Mediana: 109.616269
#
#
# /kaggle/input/historical-data-occupancy-sita/historical_data_occupancy4443.csv
#
# Modelo RF
#
# Métrica R2
# Média: 0.722174
# Desvio Padrão: 0.005296
# Mediana: 0.721303
#
# Métrica MAE
# Média: 33.496605
# Desvio Padrão: 0.154677
# Mediana: 33.504868
#
# Métrica RMSE
# Média: 64.111836
# Desvio Padrão: 1.047221
# Mediana: 64.190049
#
# Modelo RR
#
# Métrica R2
# Média: 0.107078
# Desvio Padrão: 0.005044
# Mediana: 0.107996
#
# Métrica MAE
# Média: 87.502434
# Desvio Padrão: 0.476177
# Mediana: 87.623656
#
# Métrica RMSE
# Média: 114.704430
# Desvio Padrão: 0.400211
# Mediana: 114.672223
#
# Modelo LR
#
# Métrica R2
# Média: 0.106945
# Desvio Padrão: 0.003385
# Mediana: 0.107081
#
# Métrica MAE
# Média: 87.503051
# Desvio Padrão: 0.530234
# Mediana: 87.500989
#
# Métrica RMSE
# Média: 114.701097
# Desvio Padrão: 0.914398
# Mediana: 114.775924
#
# Modelo DT
#
# Métrica R2
# Média: 0.521321
# Desvio Padrão: 0.012901
# Mediana: 0.518530
#
# Métrica MAE
# Média: 35.239708
# Desvio Padrão: 0.537365
# Mediana: 35.225799
#
# Métrica RMSE
# Média: 84.294211
# Desvio Padrão: 0.969764
# Mediana: 84.238386
#
# Modelo GBR
#
# Métrica R2
# Média: 0.320024
# Desvio Padrão: 0.005832
# Mediana: 0.319489
#
# Métrica MAE
# Média: 73.942747
# Desvio Padrão: 0.685296
# Mediana: 73.937097
#
# Métrica RMSE
# Média: 100.133730
# Desvio Padrão: 0.527587
# Mediana: 100.232534
#
#
# /kaggle/input/historical-data-occupancy-sita/historical_data_occupancy4442.csv
#
# Modelo RF
#
# Métrica R2
# Média: 0.692746
# Desvio Padrão: 0.007291
# Mediana: 0.689879
#
# Métrica MAE
# Média: 35.909985
# Desvio Padrão: 0.572684
# Mediana: 36.080625
#
# Métrica RMSE
# Média: 67.383710
# Desvio Padrão: 1.052648
# Mediana: 67.318390
#
# Modelo RR
#
# Métrica R2
# Média: 0.087271
# Desvio Padrão: 0.004239
# Mediana: 0.086763
#
# Métrica MAE
# Média: 88.603784
# Desvio Padrão: 0.336362
# Mediana: 88.569227
#
# Métrica RMSE
# Média: 116.136315
# Desvio Padrão: 0.695641
# Mediana: 116.296086
#
# Modelo LR
#
# Métrica R2
# Média: 0.087253
# Desvio Padrão: 0.005022
# Mediana: 0.085560
#
# Métrica MAE
# Média: 88.603270
# Desvio Padrão: 0.571397
# Mediana: 88.707200
#
# Métrica RMSE
# Média: 116.134621
# Desvio Padrão: 0.765935
# Mediana: 116.292498
#
# Modelo DT
#
# Métrica R2
# Média: 0.487271
# Desvio Padrão: 0.018670
# Mediana: 0.488031
#
# Métrica MAE
# Média: 37.676652
# Desvio Padrão: 0.728619
# Mediana: 37.517063
#
# Métrica RMSE
# Média: 87.271036
# Desvio Padrão: 1.329539
# Mediana: 87.322476
#
# Modelo GBR
#
# Métrica R2
# Média: 0.285807
# Desvio Padrão: 0.002808
# Mediana: 0.285032
#
# Métrica MAE
# Média: 76.376154
# Desvio Padrão: 0.353022
# Mediana: 76.460169
#
# Métrica RMSE
# Média: 102.770346
# Desvio Padrão: 0.679656
# Mediana: 102.775912
#
#
# /kaggle/input/historical-data-occupancy-sita/historical_data_occupancy4441.csv
#
# Modelo RF
#
# Métrica R2
# Média: 0.659578
# Desvio Padrão: 0.008760
# Mediana: 0.662472
#
# Métrica MAE
# Média: 41.459630
# Desvio Padrão: 0.547373
# Mediana: 41.463496
#
# Métrica RMSE
# Média: 75.487348
# Desvio Padrão: 0.844899
# Mediana: 75.522366
#
# Modelo RR
#
# Métrica R2
# Média: 0.092569
# Desvio Padrão: 0.004305
# Mediana: 0.093851
#
# Métrica MAE
# Média: 94.936108
# Desvio Padrão: 0.449136
# Mediana: 94.893898
#
# Métrica RMSE
# Média: 123.202144
# Desvio Padrão: 0.741210
# Mediana: 123.016822
#
# Modelo LR
#
# Métrica R2
# Média: 0.092548
# Desvio Padrão: 0.004374
# Mediana: 0.091123
#
# Métrica MAE
# Média: 94.935638
# Desvio Padrão: 0.604729
# Mediana: 94.766084
#
# Métrica RMSE
# Média: 123.205285
# Desvio Padrão: 0.405769
# Mediana: 123.115212
#
# Modelo DT
#
# Métrica R2
# Média: 0.457654
# Desvio Padrão: 0.016029
# Mediana: 0.459628
#
# Métrica MAE
# Média: 40.656929
# Desvio Padrão: 0.647814
# Mediana: 40.622052
#
# Métrica RMSE
# Média: 95.220205
# Desvio Padrão: 0.846089
# Mediana: 95.409273
#
# Modelo GBR
#
# Métrica R2
# Média: 0.290929
# Desvio Padrão: 0.006678
# Mediana: 0.290088
#
# Métrica MAE
# Média: 82.595486
# Desvio Padrão: 0.309641
# Mediana: 82.502742
#
# Métrica RMSE
# Média: 108.897343
# Desvio Padrão: 0.732527
# Mediana: 108.846055
#
#
# /kaggle/input/historical-data-occupancy-sita/historical_data_occupancy4440.csv
#
# Modelo RF
#
# Métrica R2
# Média: 1.000000
# Desvio Padrão: 0.000000
# Mediana: 1.000000
#
# Métrica MAE
# Média: 0.000000
# Desvio Padrão: 0.000000
# Mediana: 0.000000
#
# Métrica RMSE
# Média: 0.000000
# Desvio Padrão: 0.000000
# Mediana: 0.000000
#
# Modelo RR
#
# Métrica R2
# Média: 1.000000
# Desvio Padrão: 0.000000
# Mediana: 1.000000
#
# Métrica MAE
# Média: 0.000000
# Desvio Padrão: 0.000000
# Mediana: 0.000000
#
# Métrica RMSE
# Média: 0.000000
# Desvio Padrão: 0.000000
# Mediana: 0.000000
#
# Modelo LR
#
# Métrica R2
# Média: 1.000000
# Desvio Padrão: 0.000000
# Mediana: 1.000000
#
# Métrica MAE
# Média: 0.000000
# Desvio Padrão: 0.000000
# Mediana: 0.000000
#
# Métrica RMSE
# Média: 0.000000
# Desvio Padrão: 0.000000
# Mediana: 0.000000
#
# Modelo DT
#
# Métrica R2
# Média: 1.000000
# Desvio Padrão: 0.000000
# Mediana: 1.000000
#
# Métrica MAE
# Média: 0.000000
# Desvio Padrão: 0.000000
# Mediana: 0.000000
#
# Métrica RMSE
# Média: 0.000000
# Desvio Padrão: 0.000000
# Mediana: 0.000000
#
# Modelo GBR
#
# Métrica R2
# Média: 1.000000
# Desvio Padrão: 0.000000
# Mediana: 1.000000
#
# Métrica MAE
# Média: 0.000000
# Desvio Padrão: 0.000000
# Mediana: 0.000000
#
# Métrica RMSE
# Média: 0.000000
# Desvio Padrão: 0.000000
# Mediana: 0.000000
